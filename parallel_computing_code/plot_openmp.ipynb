# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv('openmp.csv')
data_raw = df.values
print(data_raw.shape)
# Out:
# (36, 5)

# %%
data_raw[0][3]
# Out:
# 0.48

# %%
speed_init_1 = data_raw[0][3]
speed_up_1 = [speed_init_1/data_raw[0][3],
            speed_init_1/data_raw[3][3],
            speed_init_1/data_raw[6][3],
            speed_init_1/data_raw[9][3]]

speed_init_2 = data_raw[0+12][3]
speed_up_2 = [speed_init_2/data_raw[0+12][3],
            speed_init_2/data_raw[3+12][3],
            speed_init_2/data_raw[6+12][3],
            speed_init_2/data_raw[9+12][3]]

speed_init_3 = data_raw[0+24][3]
speed_up_3 = [speed_init_3/data_raw[0+24][3],
            speed_init_3/data_raw[3+24][3],
            speed_init_3/data_raw[6+24][3],
            speed_init_3/data_raw[9+24][3]]

# %%
speed_up_2
# Out:
# [0.3184713375796178, 1.404837201015545, 4.066634002939735, 6.6963906581740975]

# %%
speed_init_1
# Out:
# 0.48

# %%
x_label=[1,2,4,8]
plt.figure()
plt.plot(x_label, speed_up_1[:], '-b')
plt.plot(x_label, speed_up_2[:], '-r')
plt.plot(x_label, speed_up_3[:], '-y')
plt.show()

# %%
n = 80
h = 1/n
log_h = [math.log(h**1.5),
         math.log(h**2),
         math.log(h**3)]

log_error_1 = [math.log(data_raw[0][4]),
             math.log(data_raw[1][4]),
             math.log(data_raw[2][4])]

log_error_2 = [math.log(data_raw[0+3][4]),
             math.log(data_raw[1+3][4]),
             math.log(data_raw[2+3][4])]
log_error_3 = [math.log(data_raw[0+6][4]),
             math.log(data_raw[1+6][4]),
             math.log(data_raw[2+6][4])]
log_error_4 = [math.log(data_raw[0+9][4]),
             math.log(data_raw[1+9][4]),
             math.log(data_raw[2+9][4])]

# %%
print(log_h)
# Out:
# [-6.573039952010823, -8.764053269347762, -13.146079904021645]

# %%
plt.figure()
plt.plot(log_h, log_error_1, '-b')
plt.plot(log_h, log_error_2, '-r')
plt.plot(log_h, log_error_3, '-y')
plt.plot(log_h, log_error_4, '-g')
plt.show()

# %%
df = pd.read_csv('openmp.csv')
data_raw = df.values
print(data_raw.shape)
# Out:
# (36, 5)

# %%
n = 80
h = 1/n
log_h = [math.log(h**1.5),
         math.log(h**2),
         math.log(h**3)]

log_error_1 = [math.log(data_raw[0+12][4]),
             math.log(data_raw[1+12][4]),
             math.log(data_raw[2+12][4])]

log_error_2 = [math.log(data_raw[0+3+12][4]),
             math.log(data_raw[1+3+12][4]),
             math.log(data_raw[2+3+12][4])]
log_error_3 = [math.log(data_raw[0+6+12][4]),
             math.log(data_raw[1+6+12][4]),
             math.log(data_raw[2+6+12][4])]
log_error_4 = [math.log(data_raw[0+9+12][4]),
             math.log(data_raw[1+9+12][4]),
             math.log(data_raw[2+9+12][4])]

# %%
plt.figure()
plt.plot(log_h, log_error_1, '-b')
plt.plot(log_h, log_error_2, '-r')
plt.plot(log_h, log_error_3, '-y')
plt.plot(log_h, log_error_4, '-g')
plt.show()

# %%
df = pd.read_csv('openmp.csv')
data_raw = df.values
print(data_raw.shape)
# Out:
# (36, 5)

# %%
n = 80
h = 1/n
log_h = [math.log(h**1.5),
         math.log(h**2),
         math.log(h**3)]

log_error_1 = [math.log(data_raw[0+24][4]),
             math.log(data_raw[1+24][4]),
             math.log(data_raw[2+24][4])]

log_error_2 = [math.log(data_raw[0+3+24][4]),
             math.log(data_raw[1+3+24][4]),
             math.log(data_raw[2+3+24][4])]
log_error_3 = [math.log(data_raw[0+6+24][4]),
             math.log(data_raw[1+6+24][4]),
             math.log(data_raw[2+6+24][4])]
log_error_4 = [math.log(data_raw[0+9+24][4]),
             math.log(data_raw[1+9+24][4]),
             math.log(data_raw[2+9+24][4])]

# %%
plt.figure()
plt.plot(log_h, log_error_1, '-b')
plt.plot(log_h, log_error_2, '-r')
plt.plot(log_h, log_error_3, '-y')
plt.plot(log_h, log_error_4, '-g')
plt.show()
